# %%
from sentinel2 import sentinel2

# %%
sentinel2??
# Out:
# Signature: sentinel2(poligono, nubes, startD, endD)
# Source:
# def sentinel2(poligono,nubes,startD,endD):
#
#     """Descarga de imágenes Sentinel 2 corregidas atmosféricamente a google Drive en carpeta Sentinel_images. Inputs
#     ruta polígono de interés, porcentaje máximo de nubes, fecha inicio del periodo de búsqueda,fecha final periodo de búsqueda.
#
#     Ejemplo: sentinel2.sentinel2("poligono.gpkg",20,"2018-04-20","2019-05-20")
#
#     Ver descripción del producto en este link
#     https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S2_SR
#
#
#     """
#
#     "version 02-07-2022"
#
#     import ee
#     ee.Initialize()
#     import datetime
#     import pandas as pd
#     import geopandas as gpd
#     import os
#     import glob
#     from shapely.geometry import MultiPoint,Point
#     import warnings
#     from IPython.display import display,Markdown
#     import sys
#     import datetime
#     warnings.filterwarnings('ignore')
#
#
#     #Colección de imágenes a analizar
#     coleccion= ee.ImageCollection("COPERNICUS/S2_SR")
#      #Enable fiona driver
#     gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
#
#     startDate= str(startD)
#     endDate= str(endD)
#     ruta = os.path.dirname(poligono) ## dir of dir of file
#     carpeta = os.path.split(ruta)[1]
#
#     pointList=[]
#     shapeFile = gpd.read_file(poligono)
#     shapeFile["Dis"]=1
#     shapeFile= shapeFile.dissolve(by='Dis')
#     crs_poligono= str(shapeFile.crs)
#
#     #Buscando vertices y transformandolo a puntos
#     a= shapeFile.bounds
#     x= [float(a.minx),float(a.minx),float(a.maxx),float(a.maxx)]
#     y = [float(a.maxy),float(a.miny),float(a.miny),float(a.maxy)]
#     df= pd.DataFrame({"x":x,"y":y})
#     geo= gpd.GeoDataFrame(df,geometry=[Point(xy) for xy in zip(df.x, df.y)],crs=crs_poligono)
#
#     #Guardandolo en coordenadas geograficas
#     area= geo.to_crs({'init': 'epsg:4326'})
#     area["x"] = area.centroid.map(lambda p: p.x)
#     area["y"] = area.centroid.map(lambda p: p.y)
#     new = area[["x","y"]].values.tolist()
#
#     roi = ee.Geometry.Polygon(new);
#
#     #Filtrando colección por nubosidad, localización y fechas
#     le8 = ee.ImageCollection(coleccion).filterDate(startDate, endDate).filterBounds(roi).filter(ee.Filter.lessThanOrEquals('CLOUDY_PIXEL_PERCENTAGE', nubes))
#
#     id_imagen= []
#     nubosidad=[]
#     fecha=[]
#
#     for images in le8.getInfo()['features']:
#         name= images["properties"]['system:index']
#         cloud=images["properties"]["CLOUDY_PIXEL_PERCENTAGE"]
#         time_unix= images["properties"]["GENERATION_TIME"]
#         time= round(time_unix/1000)
#         fecha2= datetime.datetime.fromtimestamp(time).strftime('%Y-%m-%d %H:%M:%S')
#         nubosidad.append(cloud)
#         id_imagen.append(name)
#         fecha.append(fecha2)
#
#         #Creando dataframe con metadata de imagenes
#
#         landsat= pd.DataFrame({"nubosidad":nubosidad,"id":id_imagen})
#         landsat["fecha"]=fecha
#         landsat["year"]=pd.DatetimeIndex(landsat['fecha']).year
#         landsat["day"]=pd.DatetimeIndex(landsat['fecha']).day
#         landsat["month"]=pd.DatetimeIndex(landsat['fecha']).month
#         landsat.set_index('fecha', inplace=True)
#         #landsat.sort_index(inplace=True)
#
#     if "landsat" not in locals():
#         print("No hay imágenes disponibles")
#         return
#
#     else:
#
#         print('\033' +"Lista de imágenes disponibles: "+'\033')
#         display(landsat)
#
#         download= input("¿Desea descargar las imágenes?: (escriba si o no)")
#
#     if download == "si":
#
#         #Folder puede ser cualquier carpeta que tenga respaldada en DRIVE. Sólo va el nombre no la ruta
#
#         roi = ee.Geometry.Polygon(new)
#
#         landsat = ee.ImageCollection(coleccion).filterDate(startDate, endDate).filterBounds(roi).filter(ee.Filter.lessThanOrEquals("CLOUDY_PIXEL_PERCENTAGE", nubes))
#
#         for images in landsat.getInfo()['features']:
#             image1 = ee.Image(images["id"]).select(["B2","B3","B4","B8"])
#             name= images["properties"]['system:index']
#
#             task=ee.batch.Export.image.toDrive(image= image1,
#                                            description=name,
#                                            scale= 10,
#                                            folder="Sentinel2_images",
#                                            crs= crs_poligono,
#                                            region= roi)
#             task.start()
#
#         print("Descarga comenzada!! Pueden demorar unos minutos en aparecer las imágenes en Google Drive")
#
#     else:
#         print("Descarga abortada")
# File:      c:\users\pauls\anaconda3\envs\gee\lib\sentinel2.py
# Type:      function

# %%
mask = r"C:\Users\pauls\Desktop\Proyectos\Juncal_norte\GIS\mask500gpkg.gpkg"
sentinel2(mask,20,"2022-09-27","2022-10-05")
# Out:
# Lista de imágenes disponibles:
#                      nubosidad                                      id  year  \
# fecha
# 2022-09-27 19:07:02  13.290757  20220927T142721_20220927T143005_T19HCD  2022
# 2022-09-30 19:07:53   3.912313  20220930T143731_20220930T145022_T19HCD  2022
# 2022-09-30 19:07:53   0.055188  20220930T143731_20220930T145022_T19HDD  2022
# 2022-10-02 15:40:50   0.394414  20221002T142709_20221002T143159_T19HCD  2022
# 2022-10-02 15:40:50   2.489262  20221002T142709_20221002T143159_T19HDD  2022
#
#                      day  month
# fecha
# 2022-09-27 19:07:02   27      9
# 2022-09-30 19:07:53   30      9
# 2022-09-30 19:07:53   30      9
# 2022-10-02 15:40:50    2     10
# 2022-10-02 15:40:50    2     10
# ¿Desea descargar las imágenes?: (escriba si o no) si
# Descarga comenzada!! Pueden demorar unos minutos en aparecer las imágenes en Google Drive
